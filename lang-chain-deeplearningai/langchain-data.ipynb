# %%
# !pip install langchain

from langchain import LangChain
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\python311\\lib\\site-packages\\__pycache__\\typing_extensions.cpython-311.pyc'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/2.0 MB ? eta -:--:--
#                                               0.0/2.0 MB ? eta -:--:--
#                                               0.0/2.0 MB 495.5 kB/s eta 0:00:04
#      -                                        0.1/2.0 MB 787.7 kB/s eta 0:00:03
#      -                                        0.1/2.0 MB 787.7 kB/s eta 0:00:03
#      ---                                      0.2/2.0 MB 1.1 MB/s eta 0:00:02
#      ----                                     0.2/2.0 MB 962.7 kB/s eta 0:00:02
# ...
